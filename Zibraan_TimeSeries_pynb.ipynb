# %% [markdown]
# <a href="https://colab.research.google.com/github/Zibraan/Fight_Price_Predicition/blob/main/Zibraan_TimeSeries_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample time series data
data = {'value': [10, 15, 14, 18, 25, 40, 80, 160, 320]}
df = pd.DataFrame(data)

# Apply logarithmic transformation
df['log_value'] = np.log(df['value'])

# Plot original and transformed data
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(df['value'], marker='o')
plt.title('Original Time Series')

plt.subplot(1, 2, 2)
plt.plot(df['log_value'], marker='o')
plt.title('Log Transformed Time Series')

plt.show()
